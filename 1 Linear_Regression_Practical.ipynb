# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavagrawal321/ML-Algos/blob/main/Linear_Regression_Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
os.environ["KAGGLE_CONFIG_DIR"] = "/content"

# %%
# !kaggle datasets download -d avish5787/boston-data-set
# Out:
# ...
#   0% 0.00/12.9k [00:00<?, ?B/s]
# 100% 12.9k/12.9k [00:00<00:00, 24.7MB/s]

# %%
# !unzip boston-data-set.zip
# Out:
# Archive:  boston-data-set.zip
#   inflating: boston.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("boston.csv", index_col="Unnamed: 0")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
X = df.iloc[:, :-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
Y = df.iloc[:, -1]

# %%
Y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
X.shape
# Out:
# (506, 13)

# %%
Y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.3, random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622   3.0  222.0
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301   6.0  432.0
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004   3.0  233.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986   4.0  307.0
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110   5.0  384.0
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290   3.0  223.0
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440   4.0  280.0
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247  24.0  666.0
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416   84.1  2.6463   5.0  296.0
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776   4.0  254.0
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873   4.0  305.0
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651  24.0  666.0
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944   8.0  307.0
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158  24.0  666.0
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# ...

# %%
y_train
# Out:
# 5      28.7
# 116    21.2
# 45     19.3
# 16     23.1
# 468    19.1
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: Price, Length: 354, dtype: float64

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 441    17.1
# 23     14.5
# 225    50.0
# 433    14.3
# 447    12.6
# Name: Price, Length: 152, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 3.1627098714574053

# %%
import seaborn as sns

# %%
sns.displot(y_pred - y_test, kind="kde")

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred, y_test)
# Out:
# 0.6693702691495593
